# %% [markdown]
# # 5.3. Experiments and Evaluation

# %% [markdown]
# #### Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os
import json
import numpy as np
from typing import List
import warnings
import sys

# Add the parent directory with local imports
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'lib'))

from constants import get_scenario_type

warnings.filterwarnings(
    "ignore"
)  # Disable long warnings when NaN values are encountered

# %% [markdown]
# #### Constants declaration

# %%
from constants import SCENARIOS, DIRECTIONS, PALETTES
IMAX_VALUES = ["OFF", "3", "6", "9"]
REPS = 100

# %% [markdown]
# ----
# ## Baseline performance

# %% [markdown]
# ### Probability of Congestion (TBA)

# %% [markdown]
# #### Baseline probability of congestion of Geographical Scenarios

# %%
# from stats.congestion_probability import CongestionProbability

# for scenario in SCENARIOS:
#     CongestionProbability().single_plot(scenario, )

# %% [markdown]
# ### Network Latency

# %% [markdown]
# #### Network Latency: Latitudinal Scenarios

# %%
from stats import MedianLatency

# from constants import __SCENARIOS

# FOR LANDLOCKED, I NEED TO RERUN THE BASELINE SCENARIOS FOR 30 ITERATIONS.


plot = MedianLatency()

# print(get_scenario_type("Landlocked"))
# print(DIRECTIONS.__getitem__("Landlocked"))
# print(__SCENARIOS["Landlocked"]["type"])

## ALSO POLAR NORTH IS MISSING?  IDK WHY I DIDNT RUN POLAR SOUTH AND NORTH
from matplotlib import pyplot as plt

for scenario in SCENARIOS:
    print(scenario)
    if get_scenario_type(scenario) == "Latitudinal":
        # directions = DIRECTIONS[sce]
        for direction in DIRECTIONS[scenario]:
            plot._plot(scenario, direction, "OFF", 30, plot_type="cdf")

# plot.show()

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# Landlocked
# hello, world
# Coastal
# hello, world
# Polar
# hello, world
# Equatorial
# hello, world
# IntraOrbital
# hello, world
# TransOrbital
# hello, world

# %% [markdown]
# #### Network Latency: Landlocked

# %%
scenario = "Landlocked"


# FOR LANDLOCKED, I NEED TO RERUN THE BASELINE SCENARIOS FOR 30 ITERATIONS.


for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 scenario = "Landlocked"
#       3 for direction in DIRECTIONS[scenario]:
# ----> 4     MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")
#       6 plt.tight_layout()
#       7 plt.legend()
#
# File c:\Users\morga\RiderProjects\starlink-fyp\graphs\lib\stats\median_latency.py:59, in MedianLatency._plot(self, scenario, direction, imax, reps, **kwargs)
#      54 """
#      55 NOTE: plot_type defaults to line
#      56 """
#      57 assert reps >= 0
# ---> 59 data_df = self.get_data(scenario, direction, imax, reps)
#      61 if "plot_type" in kwargs and kwargs["plot_type"] == "cdf":
#      62     self._cdf_plot(scenario, direction, data_df)
#
# ...

# %% [markdown]
# #### Network Latency: Coastal

# %%
scenario = "Coastal"

# TODO: I MIGHT NEED TO RERUN COASTAL BECAUSE I THINK THIS IS WITHOUT THE FIXED CODE.

for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Network Latency: Polar

# %%
scenario = "Polar"

for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Network Latency: Equatorial

# %%
scenario = "Equatorial"

for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Network Latency: IntraOrbital

# %%
from stats import MedianLatency

## ALSO POLAR NORTH IS MISSING?  IDK WHY I DIDNT RUN POLAR SOUTH AND NORTH
from matplotlib import pyplot as plt

scenario = "IntraOrbital"

for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# #### Network Latency: Trans Orbital

# %%
from stats import MedianLatency

## ALSO POLAR NORTH IS MISSING?  IDK WHY I DIDNT RUN POLAR SOUTH AND NORTH
from matplotlib import pyplot as plt

# for scenario in SCENARIOS:
    # if get_scenario_type(scenario) == "Orbital":
scenario = "TransOrbital"
for direction in DIRECTIONS[scenario]:
    MedianLatency()._plot(scenario, direction, "OFF", 30, plot_type="cdf")

plt.tight_layout()
plt.legend()
plt.show()
